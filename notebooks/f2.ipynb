# %% [markdown]
# # Fig 2: frequency band definitions gif
#
# This notebook creates an animated visualizer showing how frequency band ranges can affect estimates.
#
# Based on Fig 2 (a-e) of the oscillation methods paper.

# %%
import numpy as np
import matplotlib.pyplot as plt

from fooof import Bands

from neurodsp.filt import filter_signal
from neurodsp.sim import sim_powerlaw, sim_oscillation
from neurodsp.spectral import compute_spectrum, trim_spectrum

# %%
import seaborn as sns
sns.set_context('poster')

# %%
# Import custom code
from code.utils import sweep_values
from code.measures import compute_abs_power
from code.plts import plot_bar, plot_spectra, plot_timeseries
from code.gif import clear_output, _gif_plot_output

# %% [markdown]
# ## SETTINGS

# %%
# Simulation settings
n_seconds = 10
fs = 1000
exp = -1
cf = 10

# %%
# Define band ranges
BANDS = Bands({'theta' : [4, 8],
               'alpha' : [8, 12],
               'beta' : [12, 25]})
alpha_color = '#1882d9'

# %%
# Measure settings
psd_settings = {'nperseg' : 1.5 * fs}

# %%
# Plot settings
c1 = '#0000ff'
c2 = '#00693a'

titles = {'theta' : 'theta power',
          'alpha' : 'alpha power',
          'beta' : 'beta power'}

f_range = [2, 50]
xlim_sp = list(np.log10(f_range))
ylim_sp = [-3, 0.01]

xlim_t = [5000, 7000]
ylims_bar = {'theta' : [0, 1.0], 'alpha' : [0, 1.0], 'beta' : [0, 1.0]}

# %%
# Define center frequencies to sweep across
mid, low, high = 10, 6, 14
step = 0.5
cfs = sweep_values(mid, low, high, step)

# %%
# Set whether to save out
SAVE = False

# %% [markdown]
# ## DEFINE AXES

# %%
def make_axes():
    
    fig = plt.figure(figsize=(12, 4), constrained_layout=True)
    gs = fig.add_gridspec(2, 5)
    ax1 = fig.add_subplot(gs[0:, 0:2])
    ax2 = fig.add_subplot(gs[0, 2:])
    ax3 = fig.add_subplot(gs[1, 2])
    ax4 = fig.add_subplot(gs[1, 3])
    ax5 = fig.add_subplot(gs[1, 4])
    
    return fig, ax1, ax2, [ax3, ax4, ax5]

# %% [markdown]
# ## SIMULATE SIGNAL

# %%
# Simulate signal
ap = sim_powerlaw(n_seconds, fs, exp)
osc1 = sim_oscillation(n_seconds, fs, cf, variance=0.5)

sig1 = ap + osc1

# %%
# Create the second signals
sig2s = []
for cf in cfs:
    sig2s.append(ap + sim_oscillation(n_seconds, fs, cf, variance=0.5))

# %% [markdown]
# ## EXAMPLE PLOT

# %%
# Compute required measures
sig2 = sig2s[-1]
freqs1, powers1 = compute_spectrum(sig1, fs, **psd_settings)
freqs2, powers2 = compute_spectrum(sig2, fs, **psd_settings)

filt1 = filter_signal(sig1, fs, 'bandpass', BANDS['alpha'])
filt2 = filter_signal(sig2, fs, 'bandpass', BANDS['alpha'])

bp1 = {label : compute_abs_power(freqs1, powers1, band) for label, band in BANDS}
bp2 = {label : compute_abs_power(freqs2, powers2, band) for label, band in BANDS}

# %%
# Create an example panel of the visualizer
fig, ax1, ax2, bar_axes = make_axes()
plot_spectra(freqs1, [powers1, powers2], alpha=0.75, colors=[c1, c2],
             shade_ranges=[BANDS.alpha], shade_colors=[alpha_color],
             xlim=xlim_sp, ylim=ylim_sp, ax=ax1)
plot_timeseries([filt1, filt2], colors=[c1, c2],
                xlim=xlim_t, alpha=0.5, ax=ax2)
for (label, _), ax in zip(BANDS, bar_axes):
    plot_bar(bp1[label], bp2[label], color=[c1, c2],
             title=titles[label], ylim=ylims_bar[label], ax=ax)

# %% [markdown]
# ## BUILDER FUNCTION

# %%
def build_all(sig1, sig2s, sleep=0.15, save=False):
    
    ## Setup
    # Precompute measures for sig1
    freqs, pows1 = compute_spectrum(sig1, fs, **psd_settings)
    filt1 = filter_signal(sig1, fs, 'bandpass', BANDS['alpha'])
    bp1 = {}
    for label, band in BANDS:
        bp1[label] = compute_abs_power(freqs, pows1, band)
    
    # Precompute measures for sig2
    filt2s, pow2s, bp2s = [], [], []
    for sig in sig2s:
        filt2s.append(filter_signal(sig, fs, 'bandpass', BANDS['alpha']))
        cur_freqs, cur_powers = compute_spectrum(sig, fs, **psd_settings)
        pow2s.append(cur_powers)
        bp2s.append({label : compute_abs_power(cur_freqs, cur_powers, band) for label, band in BANDS})
        
        
    ## Create builds
    for b_ind, (filt2, pows2, bp2) in enumerate(zip(filt2s, pow2s, bp2s)):
        
        clear_output(wait=True)
        
        fig, ax1, ax2, bar_axes = make_axes()
        
        plot_spectra(freqs, [pows1, pows2], alpha=0.75, colors=[c1, c2],
                     shade_ranges=[BANDS.alpha], shade_colors=[alpha_color], 
                     xlim=xlim_sp, ylim=ylim_sp, ax=ax1)
        plot_timeseries([filt1, filt2], colors=[c1, c2],
                        xlim=xlim_t, alpha=0.6, ax=ax2)
        
        for (label, _), ax in zip(BANDS, bar_axes):
            plot_bar(bp1[label], bp2[label], color=[c1, c2],
                     title=titles[label], ylim=ylims_bar[label], ax=ax)

        _gif_plot_output(fig, save, b_ind, 'fig2', sleep)

# %% [markdown]
# ## ANIMATED PLOT

# %%
# Create the animated plot
build_all(sig1, sig2s, save=SAVE)
